# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy.stats as st
import scipy.special

import distribution_explorer

import bokeh.io
import bokeh.plotting
import bokeh.application
import bokeh.application.handlers
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# bokeh.io.show(distribution_explorer.explore('binomial'))

# %%
p = distribution_explorer.explore('weibull')

# %%
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="c24f0534-9aa8-4ee0-af46-a51a9925f803" data-root-id="5385"></div>

# %%
distribution_explorer.explore('discrete_unform')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-2d1bb3f99505> in <module>
# ----> 1 distribution_explorer.explore('discrete_unform')
#
# ~/Dropbox/git/distribution-explorer/distribution_explorer/distribution_explorer.py in explore(dist, params, x_min, x_max, n, slider_range_textbox, **kwargs)
#     764         dists = ", ".join(discrete_dists + continuous_dists)
#     765         raise RuntimeError(
# --> 766             f"distribution '{dist}' not supported. Allowed distributions are {dists}."
#     767         )
#     768
#
# RuntimeError: distribution 'discrete_unform' not supported. Allowed distributions are bernoulli, binomial, categorical, discrete_uniform, geometric, hypergeometric, negative_binomial, negative_binomial_mu_phi, poisson, beta, cauchy, exponential, gamma, inverse_gamma, lognormal, normal, pareto, student_t, uniform, weibull.

# %%
bokeh.io.save(p, 'normal.html')
# Out:
# /Users/Justin/anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /Users/Justin/anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# '/Users/Justin/Dropbox/git/distribution-explorer/notebooks/normal.html'

# %% [markdown]
# ### param = dict(start=0.0, end=1.0, value=0.5, step=0.02, name='test')
#
# start = bokeh.models.TextInput(value=str(param['start']), width=50)
# end = bokeh.models.TextInput(value=str(param['end']), width=50)
#
# slider = bokeh.models.Slider(start=param['start'],
#                                    end=param['end'],
#                                    value=param['value'],
#                                    step=param['step'],
#                                    title=param['name'])
#
# widgets = bokeh.layouts.layout([[start, slider, end]])
#
# bokeh.io.show(widgets)
